# %%
# ... existing code ...

# %%
import sys
import os

# Add the project root to the python path so src can be found
sys.path.append(os.path.abspath(os.path.join('../src')))

# %%
from evaluation import get_github_project_info

# %%
get_github_project_info('romilly', 'rpi-docker-tensorflow')
# Out:
# Last updated on: 2023-09-30T16:54:54Z
# Total issues: 11, Unresolved issues: 4
# Oldest unresolved issue date: 2016-10-31T04:27:53Z
# Pulls: 2
# Resolved pulls: 1
# Average time to close a pull request: 0.0 days
# Watchers: 9, Stars: 61, Forks: 30
